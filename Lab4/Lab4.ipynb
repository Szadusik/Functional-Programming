-- %% [markdown]
-- ## 1) Typy w Haskellu: type vs. newtype

-- %%
polarToCartesian :: Floating a => (a,a) -> (a,a)
polarToCartesian (r,phi) = (r * cos phi, r * sin phi)

-- %%
polarToCartesian (1,0)
-- Out:
-- (1.0,0.0)

-- %%
:t polarToCartesian
let (x1,y1) = polarToCartesian (1,pi/4)
let (x2,y2) = polarToCartesian (x1,y1) -- !!!
polarToCartesian . polarToCartesian $ (1,pi/4) -- !!!
-- Out:
-- polarToCartesian :: forall a. Floating a => (a, a) -> (a, a)
-- (0.5375741099526127,0.4593626849327842)

-- %%
type CartesianCoord' a = (a,a)
type PolarCoord' a = (a,a)
polarToCartesian' :: Floating a => PolarCoord' a -> CartesianCoord' a
polarToCartesian' (r,phi) = (r * cos phi, r * sin phi)

-- %%
:t polarToCartesian'
let (x1,y1) = polarToCartesian' (1,pi/4)
let (x2,y2) = polarToCartesian' (x1,y1) -- !!!
polarToCartesian' . polarToCartesian' $ (1,pi/4) -- !!!
-- Out:
-- polarToCartesian' :: forall a. Floating a => PolarCoord' a -> CartesianCoord' a
-- (0.5375741099526127,0.4593626849327842)

-- %%
newtype CartesianCoord'' a = MkCartesianCoord'' (a,a)
newtype PolarCoord'' a = MkPolarCoord'' (a,a)
polarToCartesian'' :: Floating a => PolarCoord'' a -> CartesianCoord'' a
polarToCartesian'' (MkPolarCoord'' (r,phi)) = MkCartesianCoord'' (r * cos phi, r * sin phi)

-- %% [raw]
-- Zalety i wady poszczególnych implementacji:
-- Pierwsza implementacja:
-- + Brak dodatkowych typów danych, wyłącznie funkcja
-- + Krótki zapis funkcji
-- - Wykorzystywanie operacji składania funkcji
--
-- Druga implementacja:
-- + Wygodny opis typu zwracanego wyniku przez funkcję
-- + Kontrolowanie otrzymywanych typów argumentów do funkcji
-- - Potrzeba wykorzystania operacji składania funkcji
--
-- Trzecia implementacja:
-- + Jeszcze większa restrykcja typów argumentów
-- + Nie trzeba wykorzystywać operacji złożenia funkcji
-- - Mniejsza czytelność w porównaniu np. z drugą implementacją

-- %% [markdown]
-- ## 2) Algebraiczne typy danych 1: product & sum types, record syntax

-- %%
data Cart2DVec' a = MkCart2DVec' a a

xCoord' :: Cart2DVec' a -> a
xCoord' (MkCart2DVec' x _) = x

yCoord' :: Cart2DVec' a -> a
yCoord' (MkCart2DVec' _ y) = y

-- %%
:i Cart2DVec'
:t MkCart2DVec'

:t MkCart2DVec' 1 2
:t MkCart2DVec' 1.0 2.0
:t MkCart2DVec' 1.0 2
:t xCoord' $ MkCart2DVec' 5 10
yCoord' $ MkCart2DVec' 5.0 10.0
-- Out:
-- MkCart2DVec' :: forall a. a -> a -> Cart2DVec' a
-- MkCart2DVec' 1 2 :: forall a. Num a => Cart2DVec' a
-- MkCart2DVec' 1.0 2.0 :: forall a. Fractional a => Cart2DVec' a
-- MkCart2DVec' 1.0 2 :: forall a. Fractional a => Cart2DVec' a
-- xCoord' $ MkCart2DVec' 5 10 :: forall a. Num a => a
-- 10.0
-- data Cart2DVec' a = MkCart2DVec' a a 	-- Defined at <interactive>:1:1

-- %%
data Cart2DVec'' a = MkCart2DVec'' {x::a, y::a}

xCoord'' :: Cart2DVec'' a -> a
xCoord'' (MkCart2DVec'' {x = xVal, y = _}) = xVal

yCoord'' :: Cart2DVec'' a -> a
yCoord'' (MkCart2DVec'' {y = yVal, x = _}) = yVal -- uwaga na kolejność x,y

:i Cart2DVec''
:t MkCart2DVec''
:t xCoord''
:t yCoord''
:t x -- dlaczego ta funkcja istnieje (skoro jej nie deklarowaliśmy/definiowaliśmy)?
:t y -- jw.?

let p23 = MkCart2DVec'' {x = 2, y = 3}
xCoord'' p23
x p23
yCoord'' p23
y p23

xCoord'' $ MkCart2DVec'' {x=1, y=2}
xCoord'' $ MkCart2DVec'' 1 2
yCoord'' $ MkCart2DVec'' {x=1, y=2}
yCoord'' $ MkCart2DVec'' 1 2
-- Out:
-- MkCart2DVec'' :: forall a. a -> a -> Cart2DVec'' a
-- xCoord'' :: forall a. Cart2DVec'' a -> a
-- yCoord'' :: forall a. Cart2DVec'' a -> a
-- x :: forall a. Cart2DVec'' a -> a
-- y :: forall a. Cart2DVec'' a -> a
-- 2
-- 2
-- 3
-- 3
-- 1
-- 1
-- 2
-- 2
-- data Cart2DVec'' a = MkCart2DVec'' {x :: a, y :: a} 	-- Defined at <interactive>:1:1

-- %% [markdown]
-- ## Zadanie

-- %%
data Cart3DVec a = MkCart3DVec a a a
xCoord''' :: Cart3DVec a -> a
xCoord''' (MkCart3DVec x _ _) = x

yCoord''' :: Cart3DVec a -> a
yCoord''' (MkCart3DVec _ y _) = y

zCoord''' :: Cart3DVec a -> a
zCoord''' (MkCart3DVec _ _ z) = z

:i Cart3DVec
:t MkCart3DVec 

:t MkCart3DVec 1 2 3
:t MkCart3DVec 1.0 2.0 3.0
:t MkCart3DVec 1.0 2 3.0

:t xCoord''' $ MkCart3DVec 5 10 15.0
yCoord''' $ MkCart3DVec 5.0 10.0 15
zCoord''' $ MkCart3DVec 5.0 10.0 15
-- Out:
-- MkCart3DVec :: forall a. a -> a -> a -> Cart3DVec a
-- MkCart3DVec 1 2 3 :: forall a. Num a => Cart3DVec a
-- MkCart3DVec 1.0 2.0 3.0 :: forall a. Fractional a => Cart3DVec a
-- MkCart3DVec 1.0 2 3.0 :: forall a. Fractional a => Cart3DVec a
-- xCoord''' $ MkCart3DVec 5 10 15.0 :: forall a. Fractional a => a
-- 10.0
-- 15.0
-- data Ghci2395.Cart3DVec a = Cart3DVec a a a 	-- Defined at <interactive>:1:20
-- data Cart3DVec a = MkCart3DVec a a a 	-- Defined at <interactive>:1:1

-- %%
data Cart3DVec a = Cart3DVec a a a
xCoord'''' :: Cart3DVec a -> a
xCoord'''' (Cart3DVec x _ _) = x

yCoord'''' :: Cart3DVec a -> a
yCoord'''' (Cart3DVec _ y _) = y

zCoord'''' :: Cart3DVec a -> a
zCoord'''' (Cart3DVec _ _ z) = z

:i Cart3DVec
:t Cart3DVec 

:t Cart3DVec 1 2 3
:t Cart3DVec 1.0 2.0 3.0
:t Cart3DVec 1.0 2 3.0

:t xCoord'''' $ Cart3DVec 5 10 15.0
yCoord'''' $ Cart3DVec 5.0 10.0 15
zCoord'''' $ Cart3DVec 5.0 10.0 15
-- Out:
-- Cart3DVec :: forall a. a -> a -> a -> Cart3DVec a
-- Cart3DVec 1 2 3 :: forall a. Num a => Cart3DVec a
-- Cart3DVec 1.0 2.0 3.0 :: forall a. Fractional a => Cart3DVec a
-- Cart3DVec 1.0 2 3.0 :: forall a. Fractional a => Cart3DVec a
-- xCoord'''' $ Cart3DVec 5 10 15.0 :: forall a. Fractional a => a
-- 10.0
-- 15.0
-- data Cart3DVec a = Cart3DVec a a a 	-- Defined at <interactive>:1:1

-- %%
data Cart3DVec a = MkCart3DVec {x::a,y::a,z::a}

xCoord1 :: Cart3DVec a -> a
xCoord1 (MkCart3DVec {x = xVal, y = _, z = _}) = xVal

yCoord1 :: Cart3DVec a -> a
yCoord1 (MkCart3DVec {y = yVal, x = _, z = _}) = yVal 

zCoord1 :: Cart3DVec a -> a
zCoord1 (MkCart3DVec {z = zVal, y = _, x = _}) = zVal 

:i Cart3DVec
:t MkCart3DVec
:t xCoord1
:t yCoord1
:t zCoord1
:t x 
:t y 
:t z

let p23 = MkCart3DVec {x = 1, y = 4, z = 5}
xCoord1 p23
x p23
yCoord1 p23
y p23
zCoord1 p23
z p23

xCoord1 $ MkCart3DVec {x=1, y=2, z=3}
xCoord1 $ MkCart3DVec 1 2 3
yCoord1 $ MkCart3DVec {x=1, y=2, z=20}
yCoord1 $ MkCart3DVec 1 2 20
zCoord1 $ MkCart3DVec {x=1, y=2, z=20}
zCoord1 $ MkCart3DVec 1 2 20
-- Out:
-- MkCart3DVec :: forall a. a -> a -> a -> Cart3DVec a
-- xCoord1 :: forall a. Cart3DVec a -> a
-- yCoord1 :: forall a. Cart3DVec a -> a
-- zCoord1 :: forall a. Cart3DVec a -> a
-- x :: forall a. Cart3DVec a -> a
-- y :: forall a. Cart3DVec a -> a
-- z :: forall a. Cart3DVec a -> a
-- 1
-- 1
-- 4
-- 4
-- 5
-- 5
-- 1
-- 1
-- 2
-- 2
-- 20
-- 20
-- data Ghci2499.Cart3DVec a = Cart3DVec a a a 	-- Defined at <interactive>:1:20
-- data Cart3DVec a = MkCart3DVec {x :: a, y :: a, z :: a} 	-- Defined at <interactive>:1:1

-- %%
data Shape = Circle Float |
             Rectangle Float Float

area :: Shape -> Float
area (Circle a) = pi * a * a
area (Rectangle a b) = a * b
area (Circle 2)
area (Rectangle 3 4)
-- Out:
-- 12.566371
-- 12.0

-- %%
data TrafficLights = Red | 
                Yellow |
                Green
actionFor :: TrafficLights -> String
actionFor Red = "Stop"
actionFor Yellow = "Przygotuj sie/zatrzymaj sie"
actionFor Green = "Ruszaj"

actionFor Red
actionFor Yellow
actionFor Green
-- Out:
-- "Stop"
-- "Przygotuj sie/zatrzymaj sie"
-- "Ruszaj"

-- %% [markdown]
-- ## 3) Algebraiczne typy danych 2: rekursja strukturalna

-- %%
data BinTree a = EmptyBT |
                 NodeBT a (BinTree a) (BinTree a)
                 deriving (Eq, Ord, Show, Read)
sumBinTree :: (Num a) => BinTree a -> a
sumBinTree EmptyBT = 0
sumBinTree (NodeBT n lt rt) = n + sumBinTree lt + sumBinTree rt

-- %%
sumBinTree EmptyBT
sumBinTree $ NodeBT 1 EmptyBT EmptyBT
sumBinTree (NodeBT 1 (NodeBT 2 EmptyBT EmptyBT) (NodeBT 3 EmptyBT EmptyBT))
-- Out:
-- 0
-- 1
-- 6

-- %%
depthOfBT :: BinTree a -> Int -- głębokość drzewa binarnego
depthOfBT EmptyBT = 0
depthOfBT (NodeBT n lt rt) = if(depthOfBT lt > depthOfBT rt) 
                                then 1 + depthOfBT lt
                                else 1 + depthOfBT rt

flattenBT :: BinTree a -> [a] 
flattenBT EmptyBT = []
flatten (NodeBT n lt rt) = flattenBT lt ++ [n] ++ flattenBT rt

preorder :: Ord a => BinTree a -> [a]
preorder EmptyBT = []
preorder (NodeBT n lt rt) = [n] ++ preorder lt ++ preorder rt

inorder :: Ord a => BinTree a -> [a]
inorder = flattenBT

postorder :: Ord a => BinTree a -> [a]
postorder EmptyBT = []
postorder (NodeBT n lt rt) = postorder lt ++ postorder rt ++ [n] 

mapBT :: (a -> b) -> BinTree a -> BinTree b
mapBT f EmptyBT = EmptyBT
mapBT f (NodeBT n lt rt) = NodeBT (f n) (mapBT f lt) (mapBT f rt)

insert :: Ord a => a -> BinTree a -> BinTree a 
insert el EmptyBT  = NodeBT el EmptyBT EmptyBT 
insert el (NodeBT n lt rt)
       | el == n = NodeBT el lt rt
       | el < n = NodeBT n (insert el lt) rt
       | el > n = NodeBT n lt (insert el rt)
       
list2BST :: Ord a => [a] -> BinTree a 
list2BST x = foldr insert EmptyBT x
-- Out:
-- Line 3: Redundant bracket
-- Found:
-- if (depthOfBT lt > depthOfBT rt) then 1 + depthOfBT lt else
--   1 + depthOfBT rt
-- Why not:
-- if depthOfBT lt > depthOfBT rt then 1 + depthOfBT lt else
--   1 + depthOfBT rtLine 34: Eta reduce
-- Found:
-- list2BST x = foldr insert EmptyBT x
-- Why not:
-- list2BST = foldr insert EmptyBT

-- %%
data Expr a = Lit a | -- literal/value a, e.g. Lit 2 = 2
              Add (Expr a) (Expr a) |
              Subtract (Expr a) (Expr a) |
              Multiply (Expr a) (Expr a)

eval :: Num a => Expr a -> a
eval (Lit n) = n
eval (Add e1 e2) = eval e1 + eval e2
eval (Subtract e1 e2) = eval e1 - eval e2
eval (Multiply e1 e2) = eval e1 * eval e2

show' :: Show a => Expr a -> String
show' (Lit n) = show n
show' (Add e1 e2) = "(" ++ show' e1 ++ "+" ++ show' e2 ++ ")"
show' (Subtract e1 e2) = "(" ++ show' e1 ++ "-" ++ show' e2 ++ ")"
show' (Multiply e1 e2) = "(" ++ show' e1 ++ "*" ++ show' e2 ++ ")"

-- %%
show' (Lit 2)
show' (Add (Lit 1) (Lit 2))
show' (Subtract (Lit 1) (Lit 3))
show' (Multiply (Lit 2) (Lit 4))
eval (Lit 1)
eval (Add (Lit 1) (Lit 2))
eval (Subtract (Lit 1) (Lit 3))
eval (Multiply (Lit 2) (Lit 4))
-- Out:
-- "2"
-- "(1+2)"
-- "(1-3)"
-- "(2*4)"
-- 1
-- 3
-- -2
-- 8

-- %% [markdown]
-- ## 5) Klasy typów i ich instancje 1: dołączanie typu do istniejącej klasy

-- %%
newtype MyInt = MkMyInt Int
instance Eq MyInt where
  (==) (MkMyInt i1) (MkMyInt i2) = i1 == i2
  
instance Ord MyInt where
  (<=) (MkMyInt i1) (MkMyInt i2) = i1 <= i2
MkMyInt 1 == MkMyInt 1
-- Out:
-- True

-- %%
MkMyInt 1 == MkMyInt 1
MkMyInt 1 == MkMyInt 2
MkMyInt 1 /= MkMyInt 2 -- dlaczego nie pojawia się błąd?

MkMyInt 1 < MkMyInt 2
-- Out:
-- True
-- False
-- True
-- True

-- %%
instance Num MyInt where
  (+) (MkMyInt i1) (MkMyInt i2) = MkMyInt (i1 + i2)
  (-) (MkMyInt i1) (MkMyInt i2) = MkMyInt (i1 - i2)
  (*) (MkMyInt i1) (MkMyInt i2) = MkMyInt (i1 * i2)
  negate (MkMyInt i)            = MkMyInt (negate i)
  abs (MkMyInt i)               = MkMyInt (abs i)
  signum (MkMyInt i)            = MkMyInt (signum i)
  fromInteger int               = MkMyInt (fromIntegral int)

-- %%
instance Show MyInt where
  show (MkMyInt i) = "MkMyInt " ++ show i

-- %%
MkMyInt 1 + MkMyInt 2
MkMyInt 5
(MkMyInt 2) * (MkMyInt 3 + MkMyInt 4)
-- Out:
-- Line 3: Redundant bracket
-- Found:
-- (MkMyInt 2) * (MkMyInt 3 + MkMyInt 4)
-- Why not:
-- MkMyInt 2 * (MkMyInt 3 + MkMyInt 4)
-- MkMyInt 3
-- MkMyInt 5
-- MkMyInt 14

-- %%
instance Eq a => Eq (BinTree a) where
  (==) (NodeBT n1 lt1 rt1) (NodeBT n2 lt2 rt2) = n1 == n2

-- %% [markdown]
-- ## 7) Moduły i importy

-- %%
module Stack (Stack(MkStack), empty, isEmpty, push, top, pop) where

empty :: Stack a
isEmpty :: Stack a -> Bool
push :: a -> Stack a -> Stack a
top :: Stack a -> a
pop :: Stack a -> (a,Stack a)

newtype Stack a = MkStack [a] deriving Show

empty = MkStack []
isEmpty (MkStack s) = null s
push x (MkStack s) = MkStack (x:s)
top (MkStack s) = head s
pop (MkStack (s:ss)) = (s,MkStack ss)

-- %%
:module -Stack
import Stack
:i Stack
:t pop
-- Out:
-- pop :: forall a. Stack a -> (a, Stack a)
-- newtype Stack a = MkStack [a] 	-- Defined at Stack.hs:9:1
-- instance [safe] Show a => Show (Stack a) -- Defined at Stack.hs:9:40

-- %%
:module Stack
import Stack ()
:i Stack
:t pop
-- Out:
-- pop :: forall a. Stack a -> (a, Stack a)
-- newtype Stack a = MkStack [a] 	-- Defined at Stack.hs:9:1
-- instance [safe] Show a => Show (Stack a) -- Defined at Stack.hs:9:40

-- %%
:module -Stack
import qualified Stack (push, pop)

:module -Stack
import Stack hiding (push, pop)

:module -Stack
import qualified Stack hiding (push, pop)

:module -Stack
import Stack as S

:module -Stack
import Stack as S (push, pop)

:module -Stack
import qualified Stack as S

:module -Stack
import qualified Stack as S (push, pop)

-- %%
module Stack (Stack(..), isEmpty, push, pop) where
empty :: Stack a
isEmpty :: Stack a -> Bool
push :: a -> Stack a -> Stack a
top :: Stack a -> a
pop :: Stack a -> (a,Stack a)

newtype Stack a = MkStack [a] deriving Show

empty = MkStack []
isEmpty (MkStack s) = null s
push x (MkStack s) = MkStack (x:s)
top (MkStack s) = head s
pop (MkStack (s:ss)) = (s,MkStack ss)

-- %%
:module -Stack
import Stack
:i Stack
:t MkStack
:i push
:i isEmpty
-- Out:
-- MkStack :: forall a. [a] -> Stack a
-- isEmpty :: Stack a -> Bool 	-- Defined at Stack.hs:11:1

-- %%
module Stack (Stack, push, pop) where
empty :: Stack a
isEmpty :: Stack a -> Bool
push :: a -> Stack a -> Stack a
top :: Stack a -> a
pop :: Stack a -> (a,Stack a)

newtype Stack a = MkStack [a] deriving Show

empty = MkStack []
isEmpty (MkStack s) = null s
push x (MkStack s) = MkStack (x:s)
top (MkStack s) = head s
pop (MkStack (s:ss)) = (s,MkStack ss)

-- %%
:module -Stack
import Stack
:i Stack
:t MkStack
-- Out:
-- <interactive>:1:1: error: Data constructor not in scope: MkStack
-- newtype Stack a = Stack.MkStack [a] 	-- Defined at Stack.hs:8:1
-- instance [safe] Show a => Show (Stack a) -- Defined at Stack.hs:8:40

-- %%
module Stack (module Stack) where
empty :: Stack a
isEmpty :: Stack a -> Bool
push :: a -> Stack a -> Stack a
top :: Stack a -> a
pop :: Stack a -> (a,Stack a)

newtype Stack a = MkStack [a] deriving Show

empty = MkStack []
isEmpty (MkStack s) = null s
push x (MkStack s) = MkStack (x:s)
top (MkStack s) = head s
pop (MkStack (s:ss)) = (s,MkStack ss)

-- %%
:module -Stack
import Stack
:i Stack
:t MkStack
-- Out:
-- MkStack :: forall a. [a] -> Stack a
-- newtype Stack a = MkStack [a] 	-- Defined at Stack.hs:8:1
-- instance [safe] Show a => Show (Stack a) -- Defined at Stack.hs:8:40
